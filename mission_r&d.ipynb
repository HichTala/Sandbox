# %%
from datasets import load_dataset # pour installer datasets: pip install datasets

# %%
dataset = load_dataset("HichTala/coco", streaming=True) # dota à la place de coco

# %%
iteration = iter(dataset["train"])

# %%
data = next(iteration)
data

# %%
data['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# # Affichage des boundings boxes

# %% [markdown]
# # Calcul de la map
